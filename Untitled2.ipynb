# %%
import os, io
import numpy as np
import pandas as pd
import rasterio

# %%
# fn = '/Users/dlee/Downloads/bio01.grd'
fn = '/Users/dlee/Downloads/bio01.gri'

# f = io.open(fn,'r', encoding='utf-32-le')
with open(fn,'rb') as f:
    data = f.read(4)

# %%
data
# Out:
# b'\x00\x00\xc0\x7f'

# %%
int.from_bytes(b'C07F')
# ascii('C07F')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a54a30b881be> in <module>
# ----> 1 int.from_bytes(b'C07F')
#       2 # ascii('C07F')
#
# TypeError: Required argument 'byteorder' (pos 2) not found

# %%
# pd.read_csv(fn, encoding='latin1')

# %%
src = rasterio.open('/Users/dlee/Downloads/bio01.grd')

# %%
src.meta
# Out:
# {'driver': 'RRASTER',
#  'dtype': 'float32',
#  'nodata': -3.3999999521443642e+38,
#  'width': 751,
#  'height': 601,
#  'count': 1,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(0.009999999999999988, 0.0, 124.5,
#         0.0, -0.009999999999999997, 39.01)}
