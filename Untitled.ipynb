# %%
import numpy as np
import pandas as pd
import os
os.environ['R_HOME'] = '/Users/dlee/anaconda3/envs/dlee/lib/R'  # The R path can be found by $ R RHOME
from rpy2.robjects import r
from rpy2.robjects import pandas2ri
import rpy2.robjects as robjects
pandas2ri.activate()

# %%
# Load dam operation results data
rf = r['load']('./data/rdata/202010/simulation_2020_MP.Rdata')
# rf = r['load']('./data/rdata/simulation_2020_MP.Rdata')
rf = r['simulation_2020_MP']

# %%
i = 0
pandas2ri.ri2py_floatvector(rf[i][6][0][-1]) # DP
pandas2ri.ri2py_floatvector(rf[i][7][3][-1]) # SDP
pandas2ri.ri2py_floatvector(rf[i][8][0][-1]) # MPC_PF
pandas2ri.ri2py_floatvector(rf[i][9][0][-1]) # MPC_DF
# Out:
# array([5.30526793e+08])

# %%
rf[i][9][0][-1]
# Out:
# R object with classes: ('numeric',) mapped to:
# <FloatVector - Python:0x7ff1cc25e188 / R:0x7ff18eb85218>
# [515140013.965531]
